# %%
import pyttsx3
import datetime
import speech_recognition as sr
import webbrowser

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
#print(voices[1].id)
engine.setProperty('voices',voices[0].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()
def choice():
    
    '''
    This function is used to take input from the user whether it wants to give input as text or as audio.
    '''
    
    print("If you want to give input as text press t or 'T', for audio input press a or 'A'")
    speak("If you want to give input as text press t or 'T', for audio input press a or 'A'")
    a = input()
    return a

def wishMe():
   
    '''
    This function is used for wishing the user according to system time. This introduces our bot as well.
    '''
    
    hour = int(datetime.datetime.now().hour)
    if hour>=0 and hour <12:
        print("Katie : Good Morning!",end=" ")
        speak("Good Morning!")
        
        
    elif hour>=12 and hour<18:
        print("Katie : Good Afternoon!",end=" ")
        speak("Good Afternoon!")
        
    else:
        print("Katie : Good Evening!",end=" ")
        speak("Good Evening!")
    
    print("I am Katie.")
    speak("I am Katie.")
    
def problemClass():
    
    '''
    It will classify the problems into different categories and will set the route for further conversation.
    '''
    
    print("Katie : I am here to help you with any problem in Udemy....At any point if you want to quit give q as input")
    speak("I am here to help you with any problem in Udemy....At any point if you want to quit give q as input")
    print("Katie : Tell me the category of your problem")
    speak("Tell me the category of your problem")
    print("Katie : Is it Account related, Payment/Refund related?")
    speak("Is it account related, payment/refunds related?")
    print("Katie : Or is it about Course Taking, Moblie App or any other type?")
    speak("Or is it about Course Taking, Mobile App or any other type?")

   
    
    
def takeCommand():
    
    '''
    It takes microphone input from the user and returns string output.
    '''
    
    r= sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshhold = 1
        audio = r.listen(source)
    
    try:
        print("Recognizing....")
        query = r.recognize_google(audio,language='en=in')
        print("User : " +query)
              
              
    except Exception as e:
              print(e)
              print("Say that again please...")
              return "None"
    
    return query


def accountt():
    
    
    '''
    It is the function which solves queries for account problems when input is text
    '''
    print("Okay!, so your problem is account related")
    speak("Okay!, so your problem is account related")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it Account Creation, Account Merging, Account Security?")
    speak("Is it Account Creation, Account Merging, Account Security?")
    
    a = input().lower()
    if 'creation' in a:
        print("So your problem is in account creation")
        speak("So your problem is in account creation")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/115012221107-Creating-and-Editing-Your-Profile")
    
    elif 'merging' in a:
        print("I understand that you have a problem in merging accounts")
        speak("I understand that you have a problem in merging accounts")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/236097968-Merging-Accounts")

    elif 'security' in a:
        print("I infer that you are concerned about your account security ")
        speak("I infer that you are concerned about your account security ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229607228-Keeping-Your-Account-Secure")
        
        

        
def accounta():
    
    
    '''
    It is the function which solves queries for account problems when input is text
    '''
    print("Okay!, so your problem is account related")
    speak("Okay!, so your problem is account related")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it Account Creation, Account Merging, Account Security?")
    speak("Is it Account Creation, Account Merging, Account Security?")
    
    a = takeCommand().lower()
    if 'creation' in a:
        print("So your problem is in account creation")
        speak("So your problem is in account creation")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/115012221107-Creating-and-Editing-Your-Profile")
    
    elif 'merging' in a:
        print("I understand that you have a problem in merging accounts")
        speak("I understand that you have a problem in merging accounts")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/236097968-Merging-Accounts")

    elif 'security' in a:
        print("I infer that you are concerned about your account security ")
        speak("I infer that you are concerned about your account security ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229607228-Keeping-Your-Account-Secure")
        



def paymentt():
    
    
    '''
    It is the function which solves problems related to payment and refunds when input is text.
    '''
    print("Okay!, so your problem is related to payments and refunds")
    speak("Okay!, so your problem is related to payments and refunds")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it Payment Methods, Refund Status, Udemy Pro ?")
    speak("Is it Payment Methods, Refund Status, Udemy Pro ?")
    
    a = input().lower()
    if 'methods' in a or 'payment' in a:
        print("So your problem is in payment methods")
        speak("So your problem is in payment methods")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/360000165907-Payment-Methods-on-Udemy")
    
    elif 'refund' in a or 'status' in a:
        print("I understand that you have a problem in refund status")
        speak("I understand that you have a problem in refund status")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/235652488-Refund-Status-Common-Questions")

    elif 'pro' in a:
        print("I infer that you are concerned about Udemy Pro ")
        speak("I infer that you are concerned about Udemy Pro ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/360037136254-Udemy-Pro-Terms-")

        
def paymenta():
    
    
    '''
    It is the function which solves problems related to payment and refunds when input is audio
    '''
    print("Okay!, so your problem is related to payments and refunds")
    speak("Okay!, so your problem is related to payments and refunds")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it Payment Methods, Refund Status, Udemy Pro ?")
    speak("Is it Payment Methods, Refund Status, Udemy Pro ?")
    
    a = takeCommand().lower()
    if 'methods' in a or 'payment' in a:
        print("So your problem is in payment methods")
        speak("So your problem is in payment methods")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/360000165907-Payment-Methods-on-Udemy")
    
    elif 'refund' in a or 'status' in a:
        print("I understand that you have a problem in refund status")
        speak("I understand that you have a problem in refund status")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/235652488-Refund-Status-Common-Questions")

    elif 'pro' in a:
        print("I infer that you are concerned about Udemy Pro ")
        speak("I infer that you are concerned about Udemy Pro ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/360037136254-Udemy-Pro-Terms-")

        

def course_t():
    
    
    '''
    It is the function which solves problems related to course taking when input is text.
    '''
    print("Okay!, so your problem is related to course taking")
    speak("Okay!, so your problem is related to course taking")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it Archiving Course, Certificate of Completion, Meaning of Icons ?")
    speak("Is it Archiving Course, Certificate of Completion, Meaning of Icons ?")
    
    a = input().lower()
    if 'archiving' in a  or 'course' in a:
        print("So your problem is in archiving your course")
        speak("So your problem is in archiving your course")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/231583427-Archiving-a-Course")
    
    elif 'certificate' in a or 'completion' in a:
        print("I understand that you have a problem with certificate of completion")
        speak("I understand that you have a problem with certificate of completion")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229603868-Certificate-of-Completion")

    elif 'meaning 'in a or 'icon' in a:
        print("I infer that you are concerned about Meaning of Icons ")
        speak("I infer that you are concerned about meaning ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229603668-What-do-the-Icons-Under-the-Lectures-Mean-")
    
    

def course_a():
    
    
    '''
    It is the function which solves problems related to course taking when input is audio.
    '''
    print("Okay!, so your problem is related to course taking")
    speak("Okay!, so your problem is related to course taking")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it Archiving Course, Certificate of Completion, Meaning of Icons ?")
    speak("Is it Archiving Course, Certificate of Completion, Meaning of Icons ?")
    
    a = takeCommand().lower()
    if 'archiving' in a or 'course' in a:
        print("So your problem is in archiving your course")
        speak("So your problem is in archiving your course")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/231583427-Archiving-a-Course")
    
    elif 'certificate' in a or 'completion' in a:
        print("I understand that you have a problem with certificate of completion")
        speak("I understand that you have a problem with certificate of completion")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229603868-Certificate-of-Completion")

    elif 'meaning ' in a or 'icon' in a:
        print("I infer that you are concerned about Meaning of Icons ")
        speak("I infer that you are concerned about meaning ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229603668-What-do-the-Icons-Under-the-Lectures-Mean-")
    
    

def app_t():
    
    
    '''
    It is the function which solves problems related to mobile app when input is text.
    '''
    print("Okay!, so your problem is related to Mobile App")
    speak("Okay!, so your problem is related to Mobile App")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it in Android App, ios App, or any general problem in mobile ?")
    speak("Is it in Android App, ios App, or any general problem in mobile  ?")
    
    a = input().lower()
    if 'android' in a:
        print("So your problem is in Android App")
        speak("So your problem is in Android App")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/sections/206458428-Android-App")
    
    elif 'ios' in a :
        print("I understand that you have a problem with ios App")
        speak("I understand that you have a problem with ios App")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/sections/206457307-iOS-App")

    elif 'general 'in a or 'moblie' in a or 'problem' in a:
        print("I infer that you are having any general problem in your mobile app ")
        speak("I infer that you are having any general problem in your mobile app ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/sections/206457227-Mobile-General")
    
    

def app_a():
    
    
    '''
    It is the function which solves problems related to mobile app when input is audio.
    '''
    print("Okay!, so your problem is related to Mobile App")
    speak("Okay!, so your problem is related to Mobile App")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it in Android App, ios App, or any general problem in mobile ?")
    speak("Is it in Android App, ios App, or any general problem in mobile  ?")
    
    a = takeCommand().lower()
    if 'android' in a:
        print("So your problem is in Android App")
        speak("So your problem is in Android App")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/sections/206458428-Android-App")
    
    elif 'ios' in a :
        print("I understand that you have a problem with ios App")
        speak("I understand that you have a problem with ios App")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/sections/206457307-iOS-App")

    elif 'general 'in a or 'moblie' in a or 'problem' in a:
        print("I infer that you are having any general problem in your mobile app ")
        speak("I infer that you are having any general problem in your mobile app ")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/sections/206457227-Mobile-General")
    

def other_t():
    
    
    '''
    It is the function which solves any other problems when input is text.
    '''
    print("Okay!, so your problem is of any different category than the given categories")
    speak("Okay!, so your problem is of any different category than the given categories")
    print("Please tell if your problem belongs in the following categories")
    speak("Please tell if your problem belongs in the following categories")
    print("Is it in PDF Loading, ,Audio or Video, or Missing Course?")
    speak("Is it in PDF Loading, Audio or Video, or Missing Course?")
    
    a = input().lower()
    if 'pdf' in a or 'loading' in a :
        print("So your problem is in PDF Loading")
        speak("So your problem is in PDF Loading")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229231107-Why-Won-t-the-PDF-Load-")
    
    elif 'audio' in a or 'video' in a  :
        print("I understand that you have a problem with audio and video")
        speak("I understand that you have a problem with audio and video")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229231227-How-to-Troubleshoot-Audio-Video-Issues")

    elif 'missing'in a or 'course' in a:
        print("I infer that you are course is missing")
        speak("I infer that you are course is missing")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229231067-How-to-Find-Your-Missing-Course")
        

def other_a():
    
    
    '''
    It is the function which solves any other problems when input is audio.
    '''
    print("Okay!, so your problem is of any different category than the given categories")
    speak("Okay!, so your problem is of any different category than the given categories")
    print("Please tell the further subcategory of your problem")
    speak("Please tell the further subcategory of your problem")
    print("Is it in PDF Loading, ,Audio or Video, or Missing Course?")
    speak("Is it in PDF Loading, Audio or Video, or Missing Course?")
    
    a = takeCommand().lower()
    if 'pdf' in a or 'loading' in a :
        print("So your problem is in PDF Loading")
        speak("So your problem is in PDF Loading")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229231107-Why-Won-t-the-PDF-Load-")
    
    elif 'audio' in a or 'video' in a  :
        print("I understand that you have a problem with audio and video")
        speak("I understand that you have a problem with audio and video")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229231227-How-to-Troubleshoot-Audio-Video-Issues")

    elif 'missing'in a or 'course' in a:
        print("I infer that you are course is missing")
        speak("I infer that you are course is missing")
        print("Okay, I got it..I will now open an article for you which will help you..")
        speak("Okay, I got it..I will now open an article for you which will help you..")
        webbrowser.open("https://support.udemy.com/hc/en-us/articles/229231067-How-to-Find-Your-Missing-Course")

    


#main class
if __name__  == "__main__":
    
    a = choice()
    wishMe()
    b='y'
    
    if a=='t' or a=='T':
        
        c=input()
        while b!='q':
            problemClass()
            problem = input().lower()
        
            
            if 'account' in problem:
                accountt()
                b=input("If you want to quit press q otherwise press any other key")
        
            elif 'payment' in problem or 'refund' in problem:
                paymentt()
                b=input("If you want to quit press q otherwise press any other key")

            
            elif 'course' in problem or 'taking' in problem:
                course_t()
                b=input("If you want to quit press q otherwise press any other key")


            
            elif 'mobile' in problem or 'app' in problem:
                app_t()
                b=input("If you want to quit press q otherwise press any other key")

            
            elif 'other' in problem:
                other_t()                
                b=input("If you want to quit press q otherwise press any other key")
                
    
    elif a=='A' or a=='a':
        q= takeCommand()
        problemClass()
        problem=takeCommand().lower()
        while b!=q:
            if 'account' in problem:
                accounta()
                b=input("If you want to quit press q otherwise press any other key")

            
            elif 'payment' in problem or 'refund' in problem:
                paymenta()
                b=input("If you want to quit press q otherwise press any other key")
        
        
            elif 'course' in problem or 'taking' in problem:
                course_a()
                b=input("If you want to quit press q otherwise press any other key")
            
            
            elif 'mobile' or 'app' in problem:
                app_a()
                b=input("If you want to quit press q otherwise press any other key")
            
            
            elif 'other' in problem:
                other_a()
                b=input("If you want to quit press q otherwise press any other key")
